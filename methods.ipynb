# %%
#Create a Greeter class with a name attribute and a greet() method that prints "Hello, my name is [name]!".
class Greeter:
    def __init__(self,name):
        self.name = name
    
    def greet(self):
        print(f"Hello, my name is {self.name}")

greeter1 = Greeter("Samul")
greeter1.greet()
# Out:
# Hello, my name is Samul

# %%
#Create a Rectangle class with width and height attributes and an area() method that returns width times height.
class Rectangle:
    def __init__(self,width,height):
        self.width = width
        self.height = height
    def area(self):
        print(f"Area = {self.height * self.width}")
rec1 = Rectangle(10,10)
rec1.area()
# Out:
# Area = 100

# %%
#Extend the BankAccount example by adding a check_balance() method that simply prints the current balance.
class BankAccount:
    def __init__(self,bal):
        self.bal = bal
    def check_balance(self):
        print(f"Balance = {self.bal}")
acc1 = BankAccount("500")
acc1.check_balance()
# Out:
# Balance = 500
