# %%
class Shape:
    def area(self):
        return 0

    def describe(self):
        return f"I am a shape with area {self.area()}"

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14159 * self.radius ** 2

class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height
class Triangle(Shape):
    def __init__(self,base,height):
        self.base = base
        self.height = height

    def area(self):
        return(0.5 * self.base * self.height)

shapes = [Circle(5), Rectangle(4, 6), Circle(3),Triangle(10,10)]

for shape in shapes:
    print(shape.describe())
# Out:
# I am a shape with area 78.53975
# I am a shape with area 24
# I am a shape with area 28.27431
# I am a shape with area 50.0

# %%
#Create an Animal base class with a info() method. Create Pet that uses super().info() and adds the owner's name.
class Animal:
    owner = "Samul"
    def info(self):
        return "Samul is my owners name"
class Pet(Animal):
    def info(self):
        base = super().info()
        return f"I am a pet and {base}"

print(Pet().info())
# Out:
# I am a pet and Samul is my owners name

# %%
#Create a list containing a Circle, Rectangle, and Triangle. Loop through and print each shape's area and description using the same method calls.
class Shape:
    def area(self):
        return 0

    def describe(self):
        return f"I am a shape with area {self.area()}"

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14159 * self.radius ** 2

class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height
class Triangle(Shape):
    def __init__(self,base,height):
        self.base = base
        self.height = height

    def area(self):
        return(0.5 * self.base * self.height)

shapes = [Circle(5), Rectangle(4, 6), Circle(3),Triangle(10,10)]

for shape in shapes:
    print(shape.describe())
# Out:
# I am a shape with area 78.53975
# I am a shape with area 24
# I am a shape with area 28.27431
# I am a shape with area 50.0
