# %%
#Create a Person class with a public name, protected _email, and private __password. Try accessing all three from outside the class.
class Person:
    def __init__(self,name,email,password):
        self.name = name
        self._email = email
        self.__password = password

p1 = Person("Samul","notsamulxd@gmail.com","password@123")
print(p1.name)
print(p1._email)
print(p1._Person__password)
# Out:
# Samul
# notsamulxd@gmail.com
# password@123

# %%
#Create a SecretVault class with a private __code. Try accessing it directly, then through name mangling. Observe the difference.
class SecretVault:
    def __init__(self,code=1234):
        self.__code = code
vault1 = SecretVault()
print(vault1._SecretVault__code)
print(vault1.__code)
# Out:
# 1234
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 7
#       3     def __init__(self,code=1234):
#       4         self.__code = code
#       5 vault1 = SecretVault()
#       6 print(vault1._SecretVault__code)
# ----> 7 print(vault1.__code)
#
# AttributeError: 'SecretVault' object has no attribute '__code'

# %%
#For the Person class above, add a verify_password(guess) method that returns True/False without exposing the actual password.
class Person:
    def __init__(self,name,email,password):
        self.name = name
        self._email = email
        self.__password = password
    def checkpassword(self,guess):
            return(self.__password == guess)

p1 = Person("Samul","notsamulxd@gmail.com","password@123")
print(p1.checkpassword("samul@123"))
print(p1.checkpassword("password@123"))
# Out:
# False
# True
