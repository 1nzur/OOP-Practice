# %%
#Create a class called Book with attributes title, author, and pages.
class Book:
    title = "book title"
    author = "book author"
    pages = "book pages"

print(Book.title,Book.author,Book.pages)
# Out:
# book title book author book pages

# %%
#Create a class called Movie with attributes for title, director, and year.
class Movie:
    title = "movie_title"
    director = "movie_director"
    year = "movie_year"

print(Movie.title, Movie.director, Movie.year)
# Out:
# movie_title movie_director movie_year

# %%
#Create a class called PhoneContact with attributes for name, phone number, and email. Print each attribute.
class PhoneContact:
    name = "Samul"
    phno = 9841424068
    email = "notsamulxd@gmail.com"

print(PhoneContact.name, PhoneContact.phno, PhoneContact.email)
# Out:
# Samul 9841424068 notsamulxd@gmail.com
